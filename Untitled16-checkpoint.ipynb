# %%
import pandas as pd
import os
import numpy as np
import pyodbc as odbc
from datetime import date,timedelta,datetime
import xlsxwriter
import seaborn as sns
import matplotlib.pyplot as plt
from openpyxl import Workbook
import openpyxl
from matplotlib.ticker import FormatStrFormatter,StrMethodFormatter
os.chdir(r'G:\FinanceReports\2024\Wk41')

# %%
# Names the needed driver, server name, and database
driver_name='SQL Server'
server_name='10.0.1.218'
database='ritascoolnet_live'
#Creates the connection string
connection_string=f"""
DRIVER={{{driver_name}}};
SERVER={server_name};
DATABASE={database};
Trust_Connection=yes"""
#Creates the Connection to SQL Server
connection=odbc.connect(connection_string)
print(connection)

# %%
#Queries the tables from SQL
#Reads in the Daily Sales from 2023
data1=pd.read_sql_query('''SELECT * FROM [dbo].[smartDailySales] Where Year(dteDate)>=2023''',connection)
#Reads in the Google Map to be able to join the inStoreID to the RitasID
data2=pd.read_sql_query('''Select intStoreID, intRitasStoreID, vchStoreState,vchStoreName,dteReopenDate from ritascoolnet_live.dbo.GOOGLE_MAP_store''',connection)
# Reads in the Daily Guest Count from 2023
data3=pd.read_sql_query('''SELECT * from ritascoolnet_live.dbo.smartDailyZTape Where intZTapeID=6 and Year(dteDate)>=2023''',connection)
# Pulls Marketing info needed like Coolnet Group, MSA, and DMA
data4=pd.read_sql_query('''Select intstoreid as intStoreID,RitasID, FC,CoolNetGroup,LegacyStoreType,State,MSAName,DMA,StoreName as ShopName,CoOpName from ritascoolnet_live.dbo.vShopDetail''',
                        connection)
# Out:
# C:\Users\jharned\AppData\Local\Temp\ipykernel_14988\162349168.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data1=pd.read_sql_query('''SELECT * FROM [dbo].[smartDailySales] Where Year(dteDate)>=2023''',connection)
# C:\Users\jharned\AppData\Local\Temp\ipykernel_14988\162349168.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data2=pd.read_sql_query('''Select intStoreID, intRitasStoreID, vchStoreState,vchStoreName,dteReopenDate from ritascoolnet_live.dbo.GOOGLE_MAP_store''',connection)
# ...

# %%
data=data1.merge(data2, on='intStoreID',how='left')
data=data.merge(data4[['intStoreID','CoOpName','LegacyStoreType']],on='intStoreID',how='left')
data['CoOpName']=data.CoOpName.fillna('LSM')
data['intRitasStoreID']=data['intRitasStoreID'].astype('int')
daily=data.rename(columns={'intRitasStoreID':'RitasID','vchStoreState':'State','vchStoreName':'ShopName'})

# %%
daily.head()
# Out:
#    intStoreID    dteDate  intRegister  bitAMPM  intProductSizeID  intQuantity  \
# 0         165 2023-03-01            1    False                 5            6
# 1         165 2023-03-01            1    False                20            2
# 2         165 2023-03-01            1    False                87            3
# 3         165 2023-03-01            1    False               112            3
# 4         165 2023-03-01            1    False              1214            2
#
#    vchProductSizeName vchProductTypeName  mnyPrice  intProductTypeSortOrder  \
# 0            Kids Ice        Italian Ice      3.99                        5
# 1        Large Gelati             Gelati      7.99                       15
# 2            Concrete  Blendini/Concrete      9.49                       35
# 3  Sprinkles Upcharge            Custard      1.50                       10
# 4    Kids SS Cup/Cone            Custard      4.59                       10
#
# ...

# %%
# names=pd.read_sql_query('''Select intstoreid as intStoreID,RitasID, FC,CoolNetGroup,LegacyStoreType,State,MSAName,DMA,StoreName as ShopName,CoOpName, Region from ritascoolnet_live.dbo.vShopDetail''',
#                         connection)
# prod_names=pd.read_sql_query('''Select intProductTypeID as ProductCode, vchProductTypeName as ProductTypeName from ritascoolnet_live.dbo.tblproducttype''',
#                         connection)
# prod_size=pd.read_sql_query('''Select intProductSizeID as ProdSizeCode, vchProductSizeName as ProductSizeName from ritascoolnet_live.dbo.tblproductsize''',
#                         connection)

# %%
# pd.read_sql_query('''select * from ritascoolnet_live.dbo.vStoreSalesNo3PDCatAll''',connection)

# %%
# daily=pd.read_sql_query('''select * from ritascoolnet_live.dbo.vStoreSalesReportingDaily''',connection)

# %%
# product=pd.read_sql_query('''select * from ritascoolnet_live.dbo.vProductSalesReportingDaily''',connection)

# %%
# daily=product.merge(names[['intStoreID','RitasID','ShopName','FC','Region','State']],on=['intStoreID','RitasID'])\
# .merge(prod_size[['ProdSizeCode','ProductSizeName']],left_on='intProductSizeID',right_on='ProdSizeCode')\
# .merge(prod_names[['ProductCode','ProductTypeName']],left_on='intproducttypeid',right_on='ProductCode')

# %%
daily['Year'],daily['Month'],daily['Day']=daily.dteDate.dt.year,daily.dteDate.dt.month,daily.dteDate.dt.day
# daily.Month=daily.Month.astype(str)
# daily.Day=daily.Day.astype(str)
daily['Month_Day']=daily.dteDate.dt.strftime('%m-%d')
daily.Month_Day
# Out:
# 0          03-01
# 1          03-01
# 2          03-01
# 3          03-01
# 4          03-01
#            ...
# 6807503    10-20
# 6807504    10-20
# 6807505    10-20
# 6807506    10-20
# 6807507    10-20
# Name: Month_Day, Length: 6807508, dtype: object

# %%
daily
# Out:
#          intStoreID    dteDate  intRegister  bitAMPM  intProductSizeID  \
# 0               165 2023-03-01            1    False                 5
# 1               165 2023-03-01            1    False                20
# 2               165 2023-03-01            1    False                87
# 3               165 2023-03-01            1    False               112
# 4               165 2023-03-01            1    False              1214
# ...             ...        ...          ...      ...               ...
# 6807503        5573 2024-10-20            1    False              1230
# 6807504        5573 2024-10-20            1    False              1246
# 6807505        5573 2024-10-20            1    False              1247
# 6807506        5573 2024-10-20            1    False              1266
# 6807507        5573 2024-10-20            1    False              1283
#
#          intQuantity  vchProductSizeName vchProductTypeName  mnyPrice  \
# ...

# %%
today=date.today().strftime('%m-%d')
today
# Out:
# '10-21'

# %%
new_row={'Year':2024,'Month_Day':'09-26','RitasID':1571,'ShopName':'5648 Circa Fishhawk Blvd-Lithia FL','mnyPosSales':0}
new_row38={'Year':2024,'Month_Day':'10-08','RitasID':1571,'ShopName':'5648 Circa Fishhawk Blvd-Lithia FL','mnyPosSales':0}
new_row39={'Year':2024,'Month_Day':'10-09','RitasID':1571,'ShopName':'5648 Circa Fishhawk Blvd-Lithia FL','mnyPosSales':0}
new_row40={'Year':2024,'Month_Day':'10-10','RitasID':1571,'ShopName':'5648 Circa Fishhawk Blvd-Lithia FL','mnyPosSales':0}
new_row41={'Year':2024,'Month_Day':'10-11','RitasID':1571,'ShopName':'5648 Circa Fishhawk Blvd-Lithia FL','mnyPosSales':0}
new_row42={'Year':2024,'Month_Day':'10-12','RitasID':1571,'ShopName':'5648 Circa Fishhawk Blvd-Lithia FL','mnyPosSales':0}
new_row43={'Year':2024,'Month_Day':'10-13','RitasID':1571,'ShopName':'5648 Circa Fishhawk Blvd-Lithia FL','mnyPosSales':0}
new_row44={'Year':2024,'Month_Day':'10-14','RitasID':1571,'ShopName':'5648 Circa Fishhawk Blvd-Lithia FL','mnyPosSales':0}
new_row1={'Year':2024,'Month_Day':'09-26','RitasID':1507,'ShopName':'2881 Clark Rd-Sarasota FL','mnyPosSales':0}
new_row2={'Year':2024,'Month_Day':'09-26','RitasID':1507,'ShopName':'2881 Clark Rd-Sarasota FL','mnyPosSales':0}
new_row3={'Year':2024,'Month_Day':'10-08','RitasID':1507,'ShopName':'2881 Clark Rd-Sarasota FL','mnyPosSales':0}
new_row4={'Year':2024,'Month_Day':'10-09','RitasID':1507,'ShopName':'2881 Clark Rd-Sarasota FL','mnyPosSales':0}
new_row5={'Year':2024,'Month_Day':'10-10','RitasID':1507,'ShopName':'2881 Clark Rd-Sarasota FL','mnyPosSales':0}
new_row6={'Year':2024,'Month_Day':'10-11','RitasID':1507,'ShopName':'2881 Clark Rd-Sarasota FL','mnyPosSales':0}
new_row7={'Year':2024,'Month_Day':'10-12','RitasID':1507,'ShopName':'2881 Clark Rd-Sarasota FL','mnyPosSales':0}
new_row8={'Year':2024,'Month_Day':'10-10','RitasID':1502,'ShopName':'1731 Lakewood Ranch Blvd.-Bradenton FL','mnyPosSales':0}
new_row9={'Year':2024,'Month_Day':'10-09','RitasID':1502,'ShopName':'1731 Lakewood Ranch Blvd.-Bradenton FL','mnyPosSales':0}
new_row10={'Year':2024,'Month_Day':'10-08','RitasID':1502,'ShopName':'1731 Lakewood Ranch Blvd.-Bradenton FL','mnyPosSales':0}
new_row11={'Year':2024,'Month_Day':'10-10','RitasID':73,'ShopName':'Fort Myers','mnyPosSales':0}
new_row55={'Year':2024,'Month_Day':'10-09','RitasID':73,'ShopName':'Fort Myers','mnyPosSales':0}
new_row12={'Year':2024,'Month_Day':'10-10','RitasID':142,'ShopName':'6200 20th St-Vero Beach FL','mnyPosSales':0}
new_row13={'Year':2024,'Month_Day':'09-26','RitasID':149,'ShopName':'Jacksonville Beach','mnyPosSales':0}
new_row14={'Year':2024,'Month_Day':'10-10','RitasID':149,'ShopName':'Jacksonville Beach','mnyPosSales':0}
new_row56={'Year':2024,'Month_Day':'10-09','RitasID':149,'ShopName':'Jacksonville Beach','mnyPosSales':0}
new_row15={'Year':2024,'Month_Day':'10-10','RitasID':536,'ShopName':'13529 Beach Blvd.-Jacksonville FL','mnyPosSales':0}
new_row57={'Year':2024,'Month_Day':'10-09','RitasID':536,'ShopName':'13529 Beach Blvd.-Jacksonville FL','mnyPosSales':0}
new_row16={'Year':2024,'Month_Day':'09-26','RitasID':764,'ShopName':'2510 N McMullen Booth Rd-Clearwater FL','mnyPosSales':0}
new_row17={'Year':2024,'Month_Day':'10-10','RitasID':764,'ShopName':'2510 N McMullen Booth Rd-Clearwater FL','mnyPosSales':0}
new_row58={'Year':2024,'Month_Day':'10-08','RitasID':764,'ShopName':'2510 N McMullen Booth Rd-Clearwater FL','mnyPosSales':0}
new_row59={'Year':2024,'Month_Day':'10-09','RitasID':764,'ShopName':'2510 N McMullen Booth Rd-Clearwater FL','mnyPosSales':0}
new_row60={'Year':2024,'Month_Day':'10-11','RitasID':764,'ShopName':'2510 N McMullen Booth Rd-Clearwater FL','mnyPosSales':0}
new_row61={'Year':2024,'Month_Day':'10-12','RitasID':764,'ShopName':'2510 N McMullen Booth Rd-Clearwater FL','mnyPosSales':0}
new_row62={'Year':2024,'Month_Day':'10-13','RitasID':764,'ShopName':'2510 N McMullen Booth Rd-Clearwater FL','mnyPosSales':0}
new_row18={'Year':2024,'Month_Day':'10-10','RitasID':836,'ShopName':'1575 Pine Ridge Rd-Naples FL','mnyPosSales':0}
new_row19={'Year':2024,'Month_Day':'10-10','RitasID':1133,'ShopName':'620 W New Haven Ave-Melbourne FL','mnyPosSales':0}
new_row20={'Year':2024,'Month_Day':'10-10','RitasID':1351,'ShopName':'11567 Regency Village Dr.-Orlando FL','mnyPosSales':0}
new_row21={'Year':2024,'Month_Day':'10-10','RitasID':1396,'ShopName':'160 Malabar Rd SW-North Palm Bay FL','mnyPosSales':0}
new_row22={'Year':2024,'Month_Day':'10-10','RitasID':1403,'ShopName':'Ocala','mnyPosSales':0}
new_row23={'Year':2024,'Month_Day':'09-26','RitasID':1416,'ShopName':'5030 W State 46 Rd-Sanford FL','mnyPosSales':0}
new_row24={'Year':2024,'Month_Day':'10-10','RitasID':1416,'ShopName':'5030 W State 46 Rd-Sanford FL','mnyPosSales':0}
new_row25={'Year':2024,'Month_Day':'10-10','RitasID':1419,'ShopName':'4255 Tamiami Trail-Port Charlotte FL','mnyPosSales':0}
new_row26={'Year':2024,'Month_Day':'10-10','RitasID':1422,'ShopName':'14337 S. US Highway 301-Wimauma FL','mnyPosSales':0}
new_row49={'Year':2024,'Month_Day':'10-11','RitasID':1422,'ShopName':'14337 S. US Highway 301-Wimauma FL','mnyPosSales':0}
new_row27={'Year':2024,'Month_Day':'10-09','RitasID':1444,'ShopName':'840 A1A N-Ponte Vedra Beach FL','mnyPosSales':0}
new_row28={'Year':2024,'Month_Day':'10-10','RitasID':1444,'ShopName':'840 A1A N-Ponte Vedra Beach FL','mnyPosSales':0}
new_row29={'Year':2024,'Month_Day':'09-26','RitasID':1449,'ShopName':'2511 FL 60 East-Valrico FL','mnyPosSales':0}
new_row30={'Year':2024,'Month_Day':'10-10','RitasID':1449,'ShopName':'2511 FL 60 East-Valrico FL','mnyPosSales':0}
new_row31={'Year':2024,'Month_Day':'09-26','RitasID':1459,'ShopName':'255 Rivertown Shops Dr.-St. Johns FL','mnyPosSales':0}
new_row32={'Year':2024,'Month_Day':'10-10','RitasID':1459,'ShopName':'255 Rivertown Shops Dr.-St. Johns FL','mnyPosSales':0}
new_row33={'Year':2024,'Month_Day':'09-26','RitasID':1467,'ShopName':'32836 US Hwy 19-Palm Harbor FL','mnyPosSales':0}
new_row34={'Year':2024,'Month_Day':'10-10','RitasID':1467,'ShopName':'32836 US Hwy 19-Palm Harbor FL','mnyPosSales':0}
new_row45={'Year':2024,'Month_Day':'10-10','RitasID':1467,'ShopName':'32836 US Hwy 19-Palm Harbor FL','mnyPosSales':0}
new_row46={'Year':2024,'Month_Day':'10-11','RitasID':1467,'ShopName':'32836 US Hwy 19-Palm Harbor FL','mnyPosSales':0}
new_row47={'Year':2024,'Month_Day':'10-12','RitasID':1467,'ShopName':'32836 US Hwy 19-Palm Harbor FL','mnyPosSales':0}
new_row48={'Year':2024,'Month_Day':'10-13','RitasID':1467,'ShopName':'32836 US Hwy 19-Palm Harbor FL','mnyPosSales':0}
new_row35={'Year':2024,'Month_Day':'10-10','RitasID':1471,'ShopName':'847 Cypress Pkwy-Kissimmee FL','mnyPosSales':0}
new_row36={'Year':2024,'Month_Day':'10-11','RitasID':1471,'ShopName':'847 Cypress Pkwy-Kissimmee FL','mnyPosSales':0}
new_row37={'Year':2024,'Month_Day':'10-12','RitasID':1471,'ShopName':'847 Cypress Pkwy-Kissimmee FL','mnyPosSales':0}
new_row50={'Year':2024,'Month_Day':'10-11','RitasID':142,'ShopName':'6200 20th St-Vero Beach FL','mnyPosSales':0}
new_row51={'Year':2024,'Month_Day':'10-12','RitasID':142,'ShopName':'6200 20th St-Vero Beach FL','mnyPosSales':0}
new_row52={'Year':2024,'Month_Day':'10-10','RitasID':39,'ShopName':'Seminole','mnyPosSales':0}
new_row53={'Year':2024,'Month_Day':'10-09','RitasID':39,'ShopName':'Seminole','mnyPosSales':0}
new_row54={'Year':2024,'Month_Day':'10-08','RitasID':39,'ShopName':'Seminole','mnyPosSales':0}
new_row63={'Year':2024,'Month_Day':'10-08','RitasID':836,'ShopName':'1575 Pine Ridge Rd-Naples FL','mnyPosSales':0}
new_row64={'Year':2024,'Month_Day':'10-09','RitasID':836,'ShopName':'1575 Pine Ridge Rd-Naples FL','mnyPosSales':0}
new_row65={'Year':2024,'Month_Day':'10-11','RitasID':836,'ShopName':'1575 Pine Ridge Rd-Naples FL','mnyPosSales':0}
new_row66={'Year':2024,'Month_Day':'10-12','RitasID':836,'ShopName':'1575 Pine Ridge Rd-Naples FL','mnyPosSales':0}
new_row67={'Year':2024,'Month_Day':'10-09','RitasID':1403,'ShopName':'Ocala','mnyPosSales':0}
new_row68={'Year':2024,'Month_Day':'10-09','RitasID':1416,'ShopName':'5030 W State 46 Rd-Sanford FL','mnyPosSales':0}
new_row69={'Year':2024,'Month_Day':'10-09','RitasID':1422,'ShopName':'14337 S. US Highway 301-Wimauma FL','mnyPosSales':0}
new_row70={'Year':2024,'Month_Day':'10-09','RitasID':1133,'ShopName':'620 W New Haven Ave-Melbourne FL','mnyPosSales':0}

fl_daily=daily[(daily.State=='FL')&((daily.dteDate>='2023-09-23'))].groupby(['Year','Month_Day','RitasID','ShopName'])['mnyPosSales'].sum().reset_index()
fl_daily=fl_daily[(fl_daily.Month_Day<=today)&(fl_daily.Month_Day>='09-23')]
fl_daily=pd.concat([fl_daily,pd.DataFrame([new_row,new_row1,new_row2,new_row3,new_row4,new_row5,new_row6,new_row7,new_row8,new_row9,new_row10,
new_row11,new_row12,new_row13,new_row14,new_row15,new_row16,new_row17,new_row18,new_row19,new_row20,
new_row21,new_row22,new_row23,new_row24,new_row25,new_row26,new_row27,new_row28,new_row29,new_row30,
new_row31,new_row32,new_row33,new_row34,new_row35,new_row36,new_row37,new_row38,
new_row39,new_row40,new_row41,new_row42,new_row43,new_row44,new_row46,new_row45,new_row47,new_row48,new_row49,
                                          new_row50,new_row51,new_row52,new_row53,new_row54,new_row55,new_row56,new_row57,
                                          new_row58,new_row59,new_row60,new_row61,new_row62,
                                          new_row63,new_row64,new_row65,new_row66,new_row67,new_row68,new_row69,new_row70])],ignore_index=True)
fl_daily=fl_daily.sort_values(by=['RitasID','Month_Day'])

# %%
fl_daily[fl_daily.ShopName.str.contains('Surfside')]
# Out:
#       Year Month_Day  RitasID                      ShopName  mnyPosSales
# 13    2023     09-23     1334  9461 Harding Ave-Surfside FL       459.52
# 981   2024     09-23     1334  9461 Harding Ave-Surfside FL       430.94
# 49    2023     09-24     1334  9461 Harding Ave-Surfside FL        43.93
# 1018  2024     09-24     1334  9461 Harding Ave-Surfside FL       341.71
# 85    2023     09-25     1334  9461 Harding Ave-Surfside FL       107.85
# 1055  2024     09-25     1334  9461 Harding Ave-Surfside FL       314.11
# 119   2023     09-26     1334  9461 Harding Ave-Surfside FL       416.82
# 1088  2024     09-26     1334  9461 Harding Ave-Surfside FL       316.78
# 151   2023     09-27     1334  9461 Harding Ave-Surfside FL       502.73
# 1118  2024     09-27     1334  9461 Harding Ave-Surfside FL       318.02
# 183   2023     09-28     1334  9461 Harding Ave-Surfside FL       604.80
# 1156  2024     09-28     1334  9461 Harding Ave-Surfside FL       372.63
# ...

# %%
wb=Workbook()
for i in list(enumerate(fl_daily.ShopName.unique())):
    fig,ax=plt.subplots(figsize=(15,10))
    sns.lineplot(data=fl_daily[fl_daily.ShopName==i[1]],x='Month_Day',y='mnyPosSales',hue='Year',
                 palette='RdYlGn',markers=True,dashes=False,style='Year',linewidth=2.5)
    plt.axvline(x='09-26', color='black', linestyle='-')
    plt.axvline(x='10-10', color='black', linestyle='-')
    plt.ylim(0,3600)
    ax.yaxis.set_major_formatter(StrMethodFormatter('${x:,.0f}'))
    plt.text(x='09-27', y=2900, s="Hurricane Helene", fontsize=12, color='black', weight='bold')
    plt.text(x='10-06', y=2900, s="Hurricane Milton", fontsize=12, color='black', weight='bold')
    ax.set_title(str(i[1])+' Sales Recovery From Hurricanes',fontsize=20)
    for x,y in zip(fl_daily[fl_daily.ShopName==i[1]].Month_Day,fl_daily[fl_daily.ShopName==i[1]].mnyPosSales):
        plt.text(x=x,y=y+150,s='${:,.0f}'.format(y),ha='center');
    ws=wb.create_sheet(title=str(i[1][:28]))
    fig.savefig(f'{i[1]}.png')  # Save the plot as an image
    img = openpyxl.drawing.image.Image(f'{i[1]}.png')  # Load the image
    ws.add_image(img, 'A1')
    ws.sheet_view.showGridLines = False
    # Save the workbook
    wb.save('Florida Sales Recovery '+str(daily.dteDate.max().strftime('%m-%d-%y'))+'.xlsx');
# Out:
# C:\Users\jharned\AppData\Local\Temp\ipykernel_14988\2555851709.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=fl_daily[(fl_daily.ShopName==i[1])&(fl_daily.Year==2024)],x='Month_Day',y='mnyPosSales',hue='Year',
# C:\Users\jharned\AppData\Local\Temp\ipykernel_14988\2555851709.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig,ax=plt.subplots(figsize=(15,10))
# C:\Users\jharned\AppData\Local\Temp\ipykernel_14988\2555851709.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=fl_daily[(fl_daily.ShopName==i[1])&(fl_daily.Year==2024)],x='Month_Day',y='mnyPosSales',hue='Year',
# ...

# %%
for i in list(enumerate(fl_daily.ShopName.unique())):
    print(str(i[1][:28]))
# Out:
# 1010 Court St-Clearwater FL
# Seminole
# Fort Myers
# 6200 20th St-Vero Beach FL
# Jacksonville Beach
# 380 A1A Beach Blvd-St August
# 13529 Beach Blvd.-Jacksonvil
# Southern Palm Crossing
# 2510 N McMullen Booth Rd-Cle
# 4587 Okeechobee Blvd.-West P
# 1575 Pine Ridge Rd-Naples FL
# 620 W New Haven Ave-Melbourn
# Coral Springs
# 9461 Harding Ave-Surfside FL
# 6782 Collins Ave-Miami Beach
# 5650 Stirling Rd-Hollywood F
# 1631 Collins Ave-Miami FL
# 11567 Regency Village Dr.-Or
# 313 Johnson St-Hollywood FL
# 3011 E Las Olas Blvd-Fort La
# 119 S Boyd Street-Winter Gar
# 160 Malabar Rd SW-North Palm
# Ocala
# 5030 W State 46 Rd-Sanford F
# 4255 Tamiami Trail-Port Char
# 14337 S. US Highway 301-Wima
# 3115 US Hwy 98 N-Lakeland FL
# 840 A1A N-Ponte Vedra Beach
# 2511 FL 60 East-Valrico FL
# 5931 International Dr-Orland
# 76020 William Burgess Blvd.-
# 255 Rivertown Shops Dr.-St.
# 32836 US Hwy 19-Palm Harbor
# 847 Cypress Pkwy-Kissimmee F
# 1305 S Military Tr.-Deerfiel
# ...

# %%
id_names=fl_daily[['RitasID','ShopName']].drop_duplicates(keep='first')
for i,j in id_names.items():
    print()
#     fig,ax=plt.subplots(figsize=(15,10))
#     sns.lineplot(data=fl_daily[fl_daily.ShopName==j],x='Month_Day',y='mnyPosSales',hue='Year',
#                  palette='RdYlGn',markers=True,dashes=False,style='Year',linewidth=2.5)
#     plt.axvline(x='09-26', color='black', linestyle='-')
#     plt.axvline(x='10-10', color='black', linestyle='-')
#     plt.ylim(0,3600)
#     ax.yaxis.set_major_formatter(StrMethodFormatter('${x:,.0f}'))
#     plt.text(x='09-27', y=2900, s="Hurricane Helene", fontsize=12, color='black', weight='bold')
#     plt.text(x='10-06', y=2900, s="Hurricane Milton", fontsize=12, color='black', weight='bold')
#     ax.set_title('Shop '+str(i)+' Sales Recovery From Hurricanes',fontsize=20)

# %%
shops=[1351,1449,1454,1467,1571]
fl=daily[(daily.RitasID.isin(shops))&(daily.dteDate>='2023-09-23')&(daily.dteDate.dt.month.between(9,10))].pivot_table(
    index=['RitasID','ShopName'],columns=['Month','Day','Year'],
    values='mnyPosSales',aggfunc='sum',fill_value=0).sort_index(axis=1,level=0)

# %%
pd.set_option('display.max_row',200)
fl.T.sort_values(by=['Month','Day'])
# Out:
# RitasID                                        1351  \
# ShopName       11567 Regency Village Dr.-Orlando FL
# Month Day Year
# 9     1   2024                               0.0000
#       2   2024                              19.1600
#       3   2024                               0.0000
#       4   2024                               0.0000
#       5   2024                               0.0000
#       6   2024                               0.0000
#       7   2024                               0.0000
#       8   2024                               0.0000
#       9   2024                               0.0000
#       10  2024                               0.0000
#       11  2024                               0.0000
#       12  2024                               0.0000
#       13  2024                               0.0000
#       14  2024                              15.2800
#       15  2024                               0.0000
#       16  2024                               0.0000
# ...

# %%
fl_dates=fl.T.sort_values(by=['Month','Day']).iloc[51:,].T
fl_dates.columns=fl_dates.columns.map(lambda x: '-'.join([str(i) for i in x]))

with pd.ExcelWriter('Specific Florida Sales Pre and Post Hurricane 2023-24 thru '+str(daily.dteDate.max().strftime('%m-%d-%y'))+'.xlsx') as writer1:
    fl_dates.to_excel(writer1,sheet_name='FL Sales',startrow=6,startcol=0)
    
    wb=writer1.book
    dollar_format=wb.add_format({'num_format':'$#,##0',
                                'align':'center',
                                'valign':'vcenter'})
    header_format=wb.add_format({'bold':True,
                                'italic':True})
    border_format=wb.add_format({'right':2,'left':2,'bottom':2,'top':2})
    word_format=wb.add_format({'align':'center','valign':'vcenter'})
    
    ws=writer1.sheets['FL Sales']
    ws.conditional_format(xlsxwriter.utility.xl_range(6,0,len(fl_dates)+6,len(fl_dates.columns)+1),
                              {'type': 'no_errors', 'format': border_format})
    
    title='Ritas Franchise Company,LLC'
    text1='FL Sales Pre and Post Hurricane 2023-2024 '
    text2='Hurricane Helene Landfall 9/26/2024'
    text3='Hurricane Milton Landfall 10/10/2024'
    test4='Source Code:dbo.vStoreSalesReportingDaily'
    ws.write(0,1,title,header_format)
    ws.write(1,1,text1,header_format)
    ws.write(2,1,text2,header_format)
    ws.write(3,1,text3,header_format)
    
    ws.set_column('C:ZZ',12, dollar_format)
    ws.set_column('A:A',12,word_format)
    ws.set_column('B:B',40,word_format)
    ws.hide_gridlines(2)
    ws.insert_image('A1','Logo.png')

# %%
daily[(daily.dteDate.dt.month==8)&(daily.dteDate.dt.day==7)&(daily.ProductTypeName!='3rd Party Delivery')]\
.pivot_table(index='FC',columns=daily.dteDate.dt.year,values=['SalesMny','ShopName'],aggfunc={'SalesMny':'sum','ShopName':'nunique'}
                                                                         ,fill_value=0).to_excel('Testing.xlsx')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 daily[(daily.dteDate.dt.month==8)&(daily.dteDate.dt.day==7)&(daily.ProductTypeName!='3rd Party Delivery')]\
#       2 .pivot_table(index='FC',columns=daily.dteDate.dt.year,values=['SalesMny','ShopName'],aggfunc={'SalesMny':'sum','ShopName':'nunique'}
#       3                                                                          ,fill_value=0).to_excel('Testing.xlsx')
#
# File ~\Anaconda3\lib\site-packages\pandas\core\generic.py:6204, in NDFrame.__getattr__(self, name)
#    6197 if (
#    6198     name not in self._internal_names_set
#    6199     and name not in self._metadata
#    6200     and name not in self._accessors
#    6201     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202 ):
#    6203     return self[name]
# ...

# %%
daily[(daily.dteDate.dt.month==8)&(daily.dteDate.dt.day==7)&(daily.ProductTypeName!='3rd Party Delivery')&(daily.FC=='Joe Toocheck')]\
.pivot_table(index='RitasID',columns=daily.dteDate.dt.year,values=['SalesMny'],aggfunc='sum'
                                                                         ,fill_value=0)

# %%
daily[(daily.dteDate.dt.month==8)&(daily.dteDate.dt.day==7)&(daily.RitasID==129)].groupby('ProductSizeName')['SalesMny'].sum()

# %%
pd.read_sql_query('''select * from ritascoolnet_live.dbo.vShopDetail''',connection)

# %%
list(enumerate(fl_daily[['RitasID','ShopName']].drop_duplicates(keep='first')))

# %%
names=list(enumerate(fl_daily.ShopName.unique()))
number=list(enumerate(fl_daily.RitasID.unique()))
for i,j in number:
    print(j," ",names[i])

# %%
names=list(fl_daily.ShopName.unique())
number=list(fl_daily.RitasID.unique())
list1=list(zip(number,names))
list(enumerate(list1))

# %%
fl_daily.ShopName.str[:20]

# %%
for i,(x,y) in enumerate(zip(number,names)):
    print(i,x,y)
